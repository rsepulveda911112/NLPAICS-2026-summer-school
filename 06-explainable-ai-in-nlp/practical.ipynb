# %% [markdown]
# # Explainable AI in NLP
#
# **NLPAICS 2026 Summer School — The Paradigm Shift** · Day 2 · Tuesday 16 June 2026
#
# **Lecturer:** Salima Lamsiyah
#
# > Before running anything, make sure the kernel is **NLPAICS 06** (menu: *Kernel → Change Kernel*). It should already be selected.

# %% [markdown]
# ## 0 · Environment check

# %%
# --- Environment check: run this cell first ---------------------------------
# It verifies you are on this lesson's kernel and that the GPU is visible.
import sys

assert ".venv" in sys.executable, (
    "Wrong kernel! In the menu choose: Kernel > Change Kernel > 'NLPAICS 06"
)
print("Kernel OK:", sys.executable)

try:
    import torch
    print("torch", torch.__version__, "| CUDA available:", torch.cuda.is_available())
    if torch.cuda.is_available():
        print("GPU:", torch.cuda.get_device_name(0))
except ImportError:
    print("torch not installed (fine if this lesson doesn't need it)")

# %% [markdown]
# ## 1 · Introduction
#
# *(Lecturer: replace from here on with your content. Suggested rhythm: short explanation → runnable cell → **Your turn** exercise. Keep cells short and runnable in order.)*

# %% [markdown]
# ## 2 · Practical

# %%
# your first example here

# %% [markdown]
# ### ✏️ Your turn
#
# *(exercise for participants)*

# %% [markdown]
# ## 3 · Wrap-up & further reading
